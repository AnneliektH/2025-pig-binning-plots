# %% [markdown]
# ## venndiagrams for unique kmers
#
# create venns for what the genome collections have in common
# kinda shitty cause idk a good format for this
#
#
# need to compare mags v mags and mags v gtdb

# %%
from matplotlib_venn import venn3
from matplotlib_venn import venn2
import matplotlib.pyplot as plt

# %%
# gtdb v gtdb 
venn2(subsets=(2099163602, 0, 459545970), set_labels=('GTDB_genomes', 'GTBD_reps'))
# (only A, only B, A ∩ B)

#plt.title("2-set Venn Diagram")
#plt.show()
plt.tight_layout()
#plt.savefig('../plots/gtdb_genomes_gtdb_reps.pdf')

# %%
# MAGall v genomes
venn2(subsets=(1143006, 2556371589, 3113595), set_labels=('MAG_all', 'GTDB_genomes'))
# (only A, only B, A ∩ B)

#plt.title("2-set Venn Diagram")
#plt.show()
plt.tight_layout()
#plt.savefig('../plots/gtdb_genomes_allMAGs,k31.pdf')

# %%
# MAGall v reps
venn2(subsets=(110408, 26151805, 276236), set_labels=('MAG_all', 'GTDB_reps'))
# (only A, only B, A ∩ B)

#plt.title("2-set Venn Diagram")
#plt.show()
plt.tight_layout()
#plt.savefig('../plots/gtdb_reps_allMAGs.pdf')

# %%
# MAG99 v reps
venn2(subsets=(94843, 26167370, 260740), set_labels=('MAG_99', 'GTDB_reps'))
# (only A, only B, A ∩ B)

#plt.title("2-set Venn Diagram")
#plt.show()
plt.tight_layout()
#plt.savefig('../plots/gtdb_reps_MAGs99.pdf')

# %%
from matplotlib_venn import venn3
import matplotlib.pyplot as plt

# Fill in actual values
venn3(subsets={
    '100': 310672,   # A only
    '010': 0,   # B only
    '001': 0,   # C only
    '110': 764551,   # A ∩ B only
    '101': 0,    # A ∩ C only
    '011': 0,    # B ∩ C only
    '111': 2787412     # A ∩ B ∩ C
}, set_labels=('All', '99', '95'))

plt.title("3-set Venn Diagram")
#plt.show()
plt.tight_layout()
plt.savefig('../plots/dereplication_MAGs.pdf')
